# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('shootings.csv')

# %%
df
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# 0     53.0      M     Asian        Shelton    WA                     True
# 1     47.0      M     White          Aloha    OR                    False
# 2     23.0      M  Hispanic        Wichita    KS                    False
# 3     32.0      M     White  San Francisco    CA                     True
# 4     39.0      M  Hispanic          Evans    CO                    False
# ...    ...    ...       ...            ...   ...                      ...
# 4890  27.0      M     Black        Atlanta    GA                    False
# 4891  23.0      M     Black    Crown Point    IN                    False
# 4892  25.0      F     White        Sedalia    MO                    False
# 4893  22.0      M     White    Kansas City    MO                    False
# 4894  31.0      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category
# 0          attack  Not fleeing        False                   Guns
# 1          attack  Not fleeing        False                   Guns
# 2           other  Not fleeing        False                Unarmed
# 3          attack  Not fleeing        False  Other unusual objects
# 4          attack  Not fleeing        False       Piercing objects
# ...           ...          ...          ...                    ...
# 4890       attack         Foot         True     Electrical devices
# 4891       attack          Car        False                   Guns
# 4892        other  Not fleeing        False                Unarmed
# 4893        other        Other        False                   Guns
# 4894       attack          Car        False                   Guns
#
# [4895 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4895 entries, 0 to 4894
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4895 non-null   int64
#  1   name                     4895 non-null   object
#  2   date                     4895 non-null   object
#  3   manner_of_death          4895 non-null   object
#  4   armed                    4895 non-null   object
#  5   age                      4895 non-null   float64
#  6   gender                   4895 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     4895 non-null   object
#  9   state                    4895 non-null   object
#  10  signs_of_mental_illness  4895 non-null   bool
#  11  threat_level             4895 non-null   object
#  12  flee                     4895 non-null   object
#  13  body_camera              4895 non-null   bool
#  14  arms_category            4895 non-null   object
# dtypes: bool(2), float64(1), int64(1), object(11)
# memory usage: 506.8+ KB

# %%
df.sort_values(by=['date'])
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# 0     53.0      M     Asian        Shelton    WA                     True
# 1     47.0      M     White          Aloha    OR                    False
# 2     23.0      M  Hispanic        Wichita    KS                    False
# 3     32.0      M     White  San Francisco    CA                     True
# 4     39.0      M  Hispanic          Evans    CO                    False
# ...    ...    ...       ...            ...   ...                      ...
# 4890  27.0      M     Black        Atlanta    GA                    False
# 4891  23.0      M     Black    Crown Point    IN                    False
# 4893  22.0      M     White    Kansas City    MO                    False
# 4892  25.0      F     White        Sedalia    MO                    False
# 4894  31.0      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category
# 0          attack  Not fleeing        False                   Guns
# 1          attack  Not fleeing        False                   Guns
# 2           other  Not fleeing        False                Unarmed
# 3          attack  Not fleeing        False  Other unusual objects
# 4          attack  Not fleeing        False       Piercing objects
# ...           ...          ...          ...                    ...
# 4890       attack         Foot         True     Electrical devices
# 4891       attack          Car        False                   Guns
# 4893        other        Other        False                   Guns
# 4892        other  Not fleeing        False                Unarmed
# 4894       attack          Car        False                   Guns
#
# [4895 rows x 15 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 4890  5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 4891  5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 4892  5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 4893  5921      William Slyter 2020-06-13              shot         gun  22.0
# 4894  5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
#      gender      race           city state  signs_of_mental_illness  \
# 0         M     Asian        Shelton    WA                     True
# 1         M     White          Aloha    OR                    False
# 2         M  Hispanic        Wichita    KS                    False
# 3         M     White  San Francisco    CA                     True
# 4         M  Hispanic          Evans    CO                    False
# ...     ...       ...            ...   ...                      ...
# 4890      M     Black        Atlanta    GA                    False
# 4891      M     Black    Crown Point    IN                    False
# 4892      F     White        Sedalia    MO                    False
# 4893      M     White    Kansas City    MO                    False
# 4894      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category
# 0          attack  Not fleeing        False                   Guns
# 1          attack  Not fleeing        False                   Guns
# 2           other  Not fleeing        False                Unarmed
# 3          attack  Not fleeing        False  Other unusual objects
# 4          attack  Not fleeing        False       Piercing objects
# ...           ...          ...          ...                    ...
# 4890       attack         Foot         True     Electrical devices
# 4891       attack          Car        False                   Guns
# 4892        other  Not fleeing        False                Unarmed
# 4893        other        Other        False                   Guns
# 4894       attack          Car        False                   Guns
#
# [4895 rows x 15 columns]

# %%
df.dropna()
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 4890  5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 4891  5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 4892  5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 4893  5921      William Slyter 2020-06-13              shot         gun  22.0
# 4894  5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
#      gender      race           city state  signs_of_mental_illness  \
# 0         M     Asian        Shelton    WA                     True
# 1         M     White          Aloha    OR                    False
# 2         M  Hispanic        Wichita    KS                    False
# 3         M     White  San Francisco    CA                     True
# 4         M  Hispanic          Evans    CO                    False
# ...     ...       ...            ...   ...                      ...
# 4890      M     Black        Atlanta    GA                    False
# 4891      M     Black    Crown Point    IN                    False
# 4892      F     White        Sedalia    MO                    False
# 4893      M     White    Kansas City    MO                    False
# 4894      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category
# 0          attack  Not fleeing        False                   Guns
# 1          attack  Not fleeing        False                   Guns
# 2           other  Not fleeing        False                Unarmed
# 3          attack  Not fleeing        False  Other unusual objects
# 4          attack  Not fleeing        False       Piercing objects
# ...           ...          ...          ...                    ...
# 4890       attack         Foot         True     Electrical devices
# 4891       attack          Car        False                   Guns
# 4892        other  Not fleeing        False                Unarmed
# 4893        other        Other        False                   Guns
# 4894       attack          Car        False                   Guns
#
# [4895 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4895 entries, 0 to 4894
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4895 non-null   int64
#  1   name                     4895 non-null   object
#  2   date                     4895 non-null   datetime64[ns]
#  3   manner_of_death          4895 non-null   object
#  4   armed                    4895 non-null   object
#  5   age                      4895 non-null   float64
#  6   gender                   4895 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     4895 non-null   object
#  9   state                    4895 non-null   object
#  10  signs_of_mental_illness  4895 non-null   bool
#  11  threat_level             4895 non-null   object
#  12  flee                     4895 non-null   object
#  13  body_camera              4895 non-null   bool
#  14  arms_category            4895 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(1), object(10)
# memory usage: 506.8+ KB

# %%
df['counter'] = "count"

# %%
df
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 4890  5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 4891  5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 4892  5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 4893  5921      William Slyter 2020-06-13              shot         gun  22.0
# 4894  5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
#      gender      race           city state  signs_of_mental_illness  \
# 0         M     Asian        Shelton    WA                     True
# 1         M     White          Aloha    OR                    False
# 2         M  Hispanic        Wichita    KS                    False
# 3         M     White  San Francisco    CA                     True
# 4         M  Hispanic          Evans    CO                    False
# ...     ...       ...            ...   ...                      ...
# 4890      M     Black        Atlanta    GA                    False
# 4891      M     Black    Crown Point    IN                    False
# 4892      F     White        Sedalia    MO                    False
# 4893      M     White    Kansas City    MO                    False
# 4894      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category counter
# 0          attack  Not fleeing        False                   Guns   count
# 1          attack  Not fleeing        False                   Guns   count
# 2           other  Not fleeing        False                Unarmed   count
# 3          attack  Not fleeing        False  Other unusual objects   count
# 4          attack  Not fleeing        False       Piercing objects   count
# ...           ...          ...          ...                    ...     ...
# 4890       attack         Foot         True     Electrical devices   count
# 4891       attack          Car        False                   Guns   count
# 4892        other  Not fleeing        False                Unarmed   count
# 4893        other        Other        False                   Guns   count
# 4894       attack          Car        False                   Guns   count
#
# [4895 rows x 16 columns]

# %%
df.groupby('date').first()
# Out:
#               id                  name   manner_of_death       armed   age  \
# date
# 2015-01-02     3            Tim Elliot              shot         gun  53.0
# 2015-01-03     5    John Paul Quintero  shot and Tasered     unarmed  23.0
# 2015-01-04     8       Matthew Hoffman              shot  toy weapon  32.0
# 2015-01-05    13   Kenneth Arnold Buck              shot         gun  22.0
# 2015-01-06    15         Brock Nichols              shot         gun  35.0
# ...          ...                   ...               ...         ...   ...
# 2020-06-09  5911          Lewis Ruffin              shot         gun  38.0
# 2020-06-11  5913  Gregorio Cruz Vanloo              shot         gun  28.0
# 2020-06-12  5916       Rayshard Brooks              shot       Taser  27.0
# 2020-06-13  5918          Hannah Fizer              shot     unarmed  25.0
# 2020-06-15  5924        Nicholas Hirsh              shot         gun  31.0
#
#            gender      race           city state  signs_of_mental_illness  \
# date
# 2015-01-02      M     Asian        Shelton    WA                     True
# 2015-01-03      M  Hispanic        Wichita    KS                    False
# 2015-01-04      M     White  San Francisco    CA                     True
# 2015-01-05      M  Hispanic       Chandler    AZ                    False
# 2015-01-06      M     White        Assaria    KS                    False
# ...           ...       ...            ...   ...                      ...
# 2020-06-09      M     Black        Orlando    FL                    False
# 2020-06-11      M     White  DeKalb County    TN                    False
# 2020-06-12      M     Black        Atlanta    GA                    False
# 2020-06-13      F     White        Sedalia    MO                    False
# 2020-06-15      M     White       Lawrence    KS                    False
#
#            threat_level         flee  body_camera          arms_category  \
# date
# 2015-01-02       attack  Not fleeing        False                   Guns
# 2015-01-03        other  Not fleeing        False                Unarmed
# 2015-01-04       attack  Not fleeing        False  Other unusual objects
# 2015-01-05       attack          Car        False                   Guns
# 2015-01-06       attack  Not fleeing        False                   Guns
# ...                 ...          ...          ...                    ...
# 2020-06-09       attack        Other        False                   Guns
# 2020-06-11        other        Other        False                   Guns
# 2020-06-12       attack         Foot         True     Electrical devices
# 2020-06-13        other  Not fleeing        False                Unarmed
# 2020-06-15       attack          Car        False                   Guns
#
#            counter
# date
# 2015-01-02   count
# 2015-01-03   count
# 2015-01-04   count
# 2015-01-05   count
# 2015-01-06   count
# ...            ...
# 2020-06-09   count
# 2020-06-11   count
# 2020-06-12   count
# 2020-06-13   count
# 2020-06-15   count
#
# [1792 rows x 15 columns]

# %%
df['date'] = df['date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
df
# Out:
#         id                name     date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  2015-01              shot         gun  53.0
# 1        4    Lewis Lee Lembke  2015-01              shot         gun  47.0
# 2        5  John Paul Quintero  2015-01  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  2015-01              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  2015-01              shot    nail gun  39.0
# ...    ...                 ...      ...               ...         ...   ...
# 4890  5916     Rayshard Brooks  2020-06              shot       Taser  27.0
# 4891  5925      Caine Van Pelt  2020-06              shot         gun  23.0
# 4892  5918        Hannah Fizer  2020-06              shot     unarmed  25.0
# 4893  5921      William Slyter  2020-06              shot         gun  22.0
# 4894  5924      Nicholas Hirsh  2020-06              shot         gun  31.0
#
#      gender      race           city state  signs_of_mental_illness  \
# 0         M     Asian        Shelton    WA                     True
# 1         M     White          Aloha    OR                    False
# 2         M  Hispanic        Wichita    KS                    False
# 3         M     White  San Francisco    CA                     True
# 4         M  Hispanic          Evans    CO                    False
# ...     ...       ...            ...   ...                      ...
# 4890      M     Black        Atlanta    GA                    False
# 4891      M     Black    Crown Point    IN                    False
# 4892      F     White        Sedalia    MO                    False
# 4893      M     White    Kansas City    MO                    False
# 4894      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category counter
# 0          attack  Not fleeing        False                   Guns   count
# 1          attack  Not fleeing        False                   Guns   count
# 2           other  Not fleeing        False                Unarmed   count
# 3          attack  Not fleeing        False  Other unusual objects   count
# 4          attack  Not fleeing        False       Piercing objects   count
# ...           ...          ...          ...                    ...     ...
# 4890       attack         Foot         True     Electrical devices   count
# 4891       attack          Car        False                   Guns   count
# 4892        other  Not fleeing        False                Unarmed   count
# 4893        other        Other        False                   Guns   count
# 4894       attack          Car        False                   Guns   count
#
# [4895 rows x 16 columns]

# %%
df.dtypes
# Out:
# id                           int64
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# arms_category               object
# counter                     object
# dtype: object

# %%
df['count'] = 1

# %%
df
# Out:
#         id                name     date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  2015-01              shot         gun  53.0
# 1        4    Lewis Lee Lembke  2015-01              shot         gun  47.0
# 2        5  John Paul Quintero  2015-01  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  2015-01              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  2015-01              shot    nail gun  39.0
# ...    ...                 ...      ...               ...         ...   ...
# 4890  5916     Rayshard Brooks  2020-06              shot       Taser  27.0
# 4891  5925      Caine Van Pelt  2020-06              shot         gun  23.0
# 4892  5918        Hannah Fizer  2020-06              shot     unarmed  25.0
# 4893  5921      William Slyter  2020-06              shot         gun  22.0
# 4894  5924      Nicholas Hirsh  2020-06              shot         gun  31.0
#
#      gender      race           city state  signs_of_mental_illness  \
# 0         M     Asian        Shelton    WA                     True
# 1         M     White          Aloha    OR                    False
# 2         M  Hispanic        Wichita    KS                    False
# 3         M     White  San Francisco    CA                     True
# 4         M  Hispanic          Evans    CO                    False
# ...     ...       ...            ...   ...                      ...
# 4890      M     Black        Atlanta    GA                    False
# 4891      M     Black    Crown Point    IN                    False
# 4892      F     White        Sedalia    MO                    False
# 4893      M     White    Kansas City    MO                    False
# 4894      M     White       Lawrence    KS                    False
#
#      threat_level         flee  body_camera          arms_category counter  \
# 0          attack  Not fleeing        False                   Guns   count
# 1          attack  Not fleeing        False                   Guns   count
# 2           other  Not fleeing        False                Unarmed   count
# 3          attack  Not fleeing        False  Other unusual objects   count
# 4          attack  Not fleeing        False       Piercing objects   count
# ...           ...          ...          ...                    ...     ...
# 4890       attack         Foot         True     Electrical devices   count
# 4891       attack          Car        False                   Guns   count
# 4892        other  Not fleeing        False                Unarmed   count
# 4893        other        Other        False                   Guns   count
# 4894       attack          Car        False                   Guns   count
#
#       count
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 4890      1
# 4891      1
# 4892      1
# 4893      1
# 4894      1
#
# [4895 rows x 17 columns]

# %%
df.dtypes
# Out:
# id                           int64
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# arms_category               object
# counter                     object
# count                        int64
# dtype: object

# %%
df = df.groupby(['date']).sum()

# %%
df
# Out:
#              id          age  signs_of_mental_illness  body_camera  count
# date
# 2015-01    8491  2767.000000                     20.0          7.0     75
# 2015-02   13818  2827.117931                     20.0          2.0     77
# 2015-03   24953  3294.000000                     27.0          7.0     91
# 2015-04   30966  3132.000000                     29.0         10.0     83
# 2015-05   32175  2541.000000                     20.0          5.0     69
# ...         ...          ...                      ...          ...    ...
# 2020-02  338287  2247.117931                      8.0          2.0     61
# 2020-03  412483  2740.353793                      7.0          6.0     73
# 2020-04  332627  2210.353793                     10.0          3.0     58
# 2020-05  454678  2883.117931                      6.0         15.0     78
# 2020-06  129844   718.000000                      2.0          3.0     22
#
# [66 rows x 5 columns]

# %%
data = df['count']

# %%
data
# Out:
# date
# 2015-01    75
# 2015-02    77
# 2015-03    91
# 2015-04    83
# 2015-05    69
#            ..
# 2020-02    61
# 2020-03    73
# 2020-04    58
# 2020-05    78
# 2020-06    22
# Name: count, Length: 66, dtype: int64

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#          count
# date
# 2015-01     75
# 2015-02     77
# 2015-03     91
# 2015-04     83
# 2015-05     69
# ...        ...
# 2020-02     61
# 2020-03     73
# 2020-04     58
# 2020-05     78
# 2020-06     22
#
# [66 rows x 1 columns]

# %% [markdown]
# #We have summed the total number of cases and got cases per month.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(12,10))
plt.plot(data)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(12,10))
plt.plot(data)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(-1,1))
data = sc.fit_transform(data)

# %%
data[:10]
# Out:
# array([[0.35897436],
#        [0.41025641],
#        [0.76923077],
#        [0.56410256],
#        [0.20512821],
#        [0.05128205],
#        [1.        ],
#        [0.76923077],
#        [0.48717949],
#        [0.43589744]])

# %%
look_back = 5
dataX, dataY = [],[]
for i in range(len(data)-(look_back)):
    dataX.append(data[i:i+look_back])
    dataY.append(data[i+look_back])

# %%
dataX = np.asanyarray(dataX)
dataY = np.asanyarray(dataY)

# %%
dataX.shape
# Out:
# (61, 5, 1)

# %%
dataY.shape
# Out:
# (61, 1)

# %%
xtrain = dataX[:50,:,:]
xtest = dataX[50:,:,:]
ytrain = dataY[:50]
ytest = dataY[50:]

# %%
xtrain.shape
# Out:
# (50, 5, 1)

# %%
xtest.shape
# Out:
# (11, 5, 1)

# %%
ytrain.shape, ytest.shape
# Out:
# ((50, 1), (11, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,LSTM,RepeatVector
# Out:
# Using TensorFlow backend.
# C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from keras.layers import Flatten,Conv1D, MaxPooling1D

# %%
model = Sequential()
model.add(Conv1D(filters =256,kernel_size=2, activation='relu', input_shape=(5,1)))
model.add(Conv1D(filters=128, kernel_size=2,activation='relu', input_shape=(5,1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(RepeatVector(30))
model.add(LSTM(128,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
history = model.fit(xtrain,ytrain,epochs=100,verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\siddh\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2351
# Epoch 2/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1895
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1420
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1088
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1134
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0993
# Epoch 7/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0936
# Epoch 8/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0959
# Epoch 9/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0954
# Epoch 10/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0926
# Epoch 11/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0895
# Epoch 12/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0903
# Epoch 13/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0911
# Epoch 14/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0890
# Epoch 15/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0876
# Epoch 16/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0880
# Epoch 17/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0886
# Epoch 18/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0881
# Epoch 19/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0871
# Epoch 20/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0862
# Epoch 21/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0859
# Epoch 22/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0870
# Epoch 23/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0867
# Epoch 24/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0857
# Epoch 25/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0851
# Epoch 26/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0850
# Epoch 27/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0851
# Epoch 28/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0845
# Epoch 29/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0840
# Epoch 30/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0832
# Epoch 31/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0829
# Epoch 32/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0824
# Epoch 33/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0815
# Epoch 34/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0809
# Epoch 35/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0813
# Epoch 36/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0794
# Epoch 37/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0791
# Epoch 38/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0782
# Epoch 39/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0779
# Epoch 40/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0762
# Epoch 41/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0758
# Epoch 42/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0755
# Epoch 43/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0731
# Epoch 44/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0764
# Epoch 45/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0739
# Epoch 46/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0699
# Epoch 47/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0711
# Epoch 48/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 49/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0669
# Epoch 50/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0681
# Epoch 51/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0644
# Epoch 52/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 53/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0637
# Epoch 54/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 55/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0620
# Epoch 56/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0542
# Epoch 57/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0561
# Epoch 58/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0532
# Epoch 59/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0496
# Epoch 60/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0471
# Epoch 61/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0453
# Epoch 62/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0447
# Epoch 63/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 64/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0501
# Epoch 65/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0625
# Epoch 66/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0585
# Epoch 67/100
# 50/50 [==============================] - ETA: 0s - loss: 0.050 - 0s 2ms/step - loss: 0.0479
# Epoch 68/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0504
# Epoch 69/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0448
# Epoch 70/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0473
# Epoch 71/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0449
# Epoch 72/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0411
# Epoch 73/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0402
# Epoch 74/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0379
# Epoch 75/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0373
# Epoch 76/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0369
# Epoch 77/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0370
# Epoch 78/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0347
# Epoch 79/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0354
# Epoch 80/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 81/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0350
# Epoch 82/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0448
# Epoch 83/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0478
# Epoch 84/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0541
# Epoch 85/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0350
# Epoch 86/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0504
# Epoch 87/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0382
# Epoch 88/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0397
# Epoch 89/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0374
# Epoch 90/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0339
# Epoch 91/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 92/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0327
# Epoch 93/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0318
# Epoch 94/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 95/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0284
# Epoch 96/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0311
# Epoch 97/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0272
# Epoch 98/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0303
# Epoch 99/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 100/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0279

# %%
pred = model.predict(xtest)
pred = sc.inverse_transform(pred)

# %%
pred
# Out:
# array([[70.33751 ],
#        [64.329475],
#        [64.06317 ],
#        [69.65966 ],
#        [69.915054],
#        [63.853497],
#        [82.570015],
#        [69.18646 ],
#        [72.495   ],
#        [60.922543],
#        [78.38532 ]], dtype=float32)

# %%
ytest = sc.inverse_transform(ytest)

# %%
plt.figure(figsize = (25,12))
plt.plot(ytest)
plt.plot(pred)
plt.legend('Test', 'Predicted')
plt.show()
# Out:
# C:\Users\siddh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Legend does not support 'T' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   after removing the cwd from sys.path.
# C:\Users\siddh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Legend does not support 'e' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   after removing the cwd from sys.path.
# C:\Users\siddh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   after removing the cwd from sys.path.
# C:\Users\siddh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Legend does not support 't' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   after removing the cwd from sys.path.
